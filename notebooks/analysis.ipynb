# %%
import pandas as pd

# %%
excel_file_path = "/Users/aynat/Developer/hospital-management-streamlit/data_sheets/bhopal.xlsx"
df = pd.read_excel(excel_file_path)

# %%
df
# Out:
#       place patience_name    category age_group gender       date  \
# 0    BHOPAL         amit   cold cough     18-21   male 2023-02-12
# 1    BHOPAL         amit      maleria     22-25   male 2023-02-12
# 2    BHOPAL         amit      typhoid     14-17   male 2023-02-12
# 3    BHOPAL         amit        fever     26-29   male 2023-02-12
# 4    BHOPAL         amit      acidity     30-33   male 2023-02-12
# ..      ...           ...         ...       ...    ...        ...
# 99   BHOPAL         amit   cold cough     30-33   male 2023-03-01
# 100  BHOPAL         amit      maleria     18-21   male 2023-03-01
# 101  BHOPAL         amit      typhoid     22-25   male 2023-03-01
# 102  BHOPAL         amit        fever     14-17   male 2023-03-01
# 103  BHOPAL         amit      acidity     26-29   male 2023-03-01
#
#             doctorname
# 0          AMIT GURJAR
# 1    PRATEEKSHA GURJAR
# 2     DEEPENDRA GURJAR
# 3       SOURABH GURJAR
# 4         SUMIT GURJAR
# ..                 ...
# ...

# %%
pd.grouped_df = df.groupby('category')

# %%
pd.grouped_df

# %%
disease = df['category'].value_counts().reset_index()

# %%
disease
# Out:
#      category  count
# 0     typhoid     29
# 1  cold cough     27
# 2     maleria     16
# 3       fever     16
# 4     acidity     16

# %%
category_counts = df['category'].value_counts().reset_index()

# %%
category_counts
# Out:
#      category  count
# 0     typhoid     29
# 1  cold cough     27
# 2     maleria     16
# 3       fever     16
# 4     acidity     16

# %%
category_counts = df['category'].value_counts().reset_index()

# %%
age_group_counts = df['age_group'].value_counts().reset_index()

# %%
age_group_counts
# Out:
#   age_group  count
# 0     18-21     21
# 1     22-25     21
# 2     14-17     21
# 3     26-29     21
# 4     30-33     20

# %%
gender_counts = df['gender'].value_counts().reset_index()

# %%
gender_counts
# Out:
#    gender  count
# 0    male     60
# 1  female     44

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df_date = df.sort_values(by='date')

# %%
df_date
# Out:
#       place patience_name    category age_group gender       date  \
# 0    BHOPAL         amit   cold cough     18-21   male 2023-02-12
# 1    BHOPAL         amit      maleria     22-25   male 2023-02-12
# 2    BHOPAL         amit      typhoid     14-17   male 2023-02-12
# 3    BHOPAL         amit        fever     26-29   male 2023-02-12
# 4    BHOPAL         amit      acidity     30-33   male 2023-02-12
# ..      ...           ...         ...       ...    ...        ...
# 98   BHOPAL         amit      acidity     26-29   male 2023-03-01
# 99   BHOPAL         amit   cold cough     30-33   male 2023-03-01
# 100  BHOPAL         amit      maleria     18-21   male 2023-03-01
# 101  BHOPAL         amit      typhoid     22-25   male 2023-03-01
# 103  BHOPAL         amit      acidity     26-29   male 2023-03-01
#
#             doctorname
# 0          AMIT GURJAR
# 1    PRATEEKSHA GURJAR
# 2     DEEPENDRA GURJAR
# 3       SOURABH GURJAR
# 4         SUMIT GURJAR
# ..                 ...
# ...

# %%
count_doctor = df['doctorname'].value_counts().reset_index()

# %%
count_doctor
# Out:
#           doctorname  count
# 0        AMIT GURJAR     21
# 1  PRATEEKSHA GURJAR     21
# 2   DEEPENDRA GURJAR     21
# 3     SOURABH GURJAR     21
# 4       SUMIT GURJAR     20

# %%
excel_file_path_admin = "/Users/aynat/Developer/Dev-Prpphests-visual-dashboard/streamlit/data/main_admin.xlsx"
df_admin = pd.read_excel(excel_file_path_admin)

# %%
df_admin
# Out:
#          place patience_name    category age_group gender       date  \
# 0       BHOPAL         amit   cold cough     18-21   male 2023-02-12
# 1       BHOPAL         amit      maleria     22-25   male 2023-02-12
# 2       BHOPAL         amit      typhoid     14-17   male 2023-02-12
# 3       BHOPAL         amit        fever     26-29   male 2023-02-12
# 4       BHOPAL         amit      acidity     30-33   male 2023-02-12
# ..         ...           ...         ...       ...    ...        ...
# 396  GADARWARA         amit   cold cough     30-33   male 2023-02-27
# 397  GADARWARA         amit      maleria     18-21   male 2023-02-27
# 398  GADARWARA         amit      typhoid     22-25   male 2023-02-27
# 399  GADARWARA         amit        fever     14-17   male 2023-02-27
# 400  GADARWARA         amit      acidity     26-29   male 2023-02-28
#
#             doctorname
# 0          AMIT GURJAR
# 1    PRATEEKSHA GURJAR
# 2     DEEPENDRA GURJAR
# 3       SOURABH GURJAR
# ...

# %%
excel_file_jabalpur = "/Users/aynat/Developer/Dev-Prpphests-visual-dashboard/streamlit/data/jabalpur.xlsx"
df_jabalpur = pd.read_excel(excel_file_jabalpur)
df_jabalpur
# Out:
#         place patience_name    category age_group gender       date  \
# 0    JABALPUR         amit   cold cough     18-21   male 2023-02-12
# 1    JABALPUR         amit      maleria     22-25   male 2023-02-12
# 2    JABALPUR         amit      typhoid     14-17   male 2023-02-12
# 3    JABALPUR         amit        fever     26-29   male 2023-02-12
# 4    JABALPUR         amit      acidity     30-33   male 2023-02-12
# ..        ...           ...         ...       ...    ...        ...
# 150  JABALPUR         amit      typhoid     30-33   male 2023-04-17
# 151  JABALPUR         amit        fever     18-21   male 2023-04-18
# 152  JABALPUR         amit      acidity     22-25   male 2023-04-19
# 153  JABALPUR         amit   cold cough     14-17   male 2023-04-20
# 154  JABALPUR         amit      maleria     26-29   male 2023-04-21
#
#       doctorname
# 0    UTTAM SAGAR
# 1        VISKASH
# 2           RAMU
# 3          SAMAR
# 4       ASHUTOSH
# ..           ...
# 150        SAMAR
# ...

# %%
df['category'].value_counts().reset_index()
# Out:
#      category  count
# 0     typhoid    113
# 1  cold cough    112
# 2     maleria     64
# 3       fever     56
# 4     acidity     56
